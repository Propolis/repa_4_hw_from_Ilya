# %%
import random
from enum import Enum
from rich.console import Console
from rich.table import Table
from rich.panel import Panel

console = Console()

class Names(str, Enum):
    JOHN = "Джон Леннон"
    PAUL = "Пол Маккартни"
    GEORGE = "Джордж Харрисон"
    RINGO = "Ринго Старр"

class Beetle:
    health_points: int
    max_hp: int
    name: Names

    def __init__(
        self,
        health_points: int = 100,
        name: Names = Names.JOHN,
    ) -> None:
        self.health_points = health_points
        self.max_hp = health_points
        self.name = name

    def __eq__(self, other: "Beetle") -> bool:
        return self.health_points == other.health_points

    def __lt__(self, other: "Beetle") -> bool:
        return self.health_points < other.health_points

    def __le__(self, other: "Beetle") -> bool:
        return self.health_points <= other.health_points

    def __str__(self) -> str:
        return f'Beetle(name="{self.name}", hp={self.health_points!r})'

    def styling(self) -> str:
        if self.name is Names.JOHN:
            return "в стиле Джона"
        elif self.name is Names.PAUL:
            return "в стиле Пола"
        elif self.name is Names.GEORGE:
            return "в стиле Джорджа"
        return "в стиле Ринго"

    def attack(self, other: "Beetle") -> int:
        damage = random.randint(5, 25)
        other.health_points -= damage
        return damage

    def is_alive(self) -> bool:
        return self.health_points > 0

    def heal(self, amount: int):
        self.health_points = min(self.max_hp, self.health_points + amount)

class BeetlesArmy:
    def __init__(
        self,
        beetles_name: Names,
        army_id: str,
        beetles_army_size: int = 20,
        beetles_max_health_points: int = 100,
    ):
        self.beetles_list = []
        self.beetles_name = beetles_name
        self.army_id = army_id
        for _ in range(beetles_army_size):
            hp = random.randint(30, beetles_max_health_points)
            self.beetles_list.append(Beetle(health_points=hp, name=self.beetles_name))

    def __len__(self) -> int:
        return len([b for b in self.beetles_list if b.is_alive()])

    def get_fighter(self) -> Beetle | None:
        for b in self.beetles_list:
            if b.is_alive():
                return b
        return None

def battle(army1: BeetlesArmy, army2: BeetlesArmy):
    console.print(Panel.fit(f"[bold yellow]БИТВА НАЧАЛАСЬ![/bold yellow]\n{army1.beetles_name} ({army1.army_id}) VS {army2.beetles_name} ({army2.army_id})", border_style="red"))
    
    turn = 1
    while len(army1) > 0 and len(army2) > 0:
        attacker_army, defender_army = (army1, army2) if turn % 2 == 1 else (army2, army1)
        
        attacker = attacker_army.get_fighter()
        defender = defender_army.get_fighter()
        
        if attacker and defender:
            dmg = attacker.attack(defender)
            msg = f"[bold cyan]{attacker.name}[/bold cyan] ({attacker_army.army_id}) атакует [bold magenta]{defender.name}[/bold magenta] ({defender_army.army_id}) {attacker.styling()} на [white]{dmg}[/white] урона!"
            
            if not defender.is_alive():
                msg += f"\n[bold red]ЖУК УБИТ![/bold red] {attacker.name} получает +10 HP бонус."
                attacker.heal(10)
            
            console.print(msg)
        
        turn += 1
        if turn > 1000: break
    
    winner = army1 if len(army1) > 0 else army2
    console.print(Panel(f"[bold green]ПОБЕДИТЕЛЬ: {winner.beetles_name} ({winner.army_id})! [/bold green]", border_style="gold1"))

def main():
    console.print(Panel.fit("=== Настройка Битвы Жуков ===", style="bold magenta"))
    
    try:
        id1 = input("ID первой армии: ") or "A"
        choice1 = input("Герой 1 (1-4): ") or "1"
        size1 = int(input("Размер 1: ") or "3")
        
        id2 = input("ID второй армии: ") or "B"
        choice2 = input("Герой 2 (1-4): ") or "2"
        size2 = int(input("Размер 2: ") or "3")
        
        name_map = {"1": Names.JOHN, "2": Names.PAUL, "3": Names.GEORGE, "4": Names.RINGO}
        army1 = BeetlesArmy(name_map.get(choice1, Names.JOHN), id1, size1)
        army2 = BeetlesArmy(name_map.get(choice2, Names.PAUL), id2, size2)
        
        battle(army1, army2)
    except Exception as e:
        print(f"Ошибка: {e}")

if __name__ == "__main__":
    main()
# Out:
# ╭───────────────────────────────╮
# │ === Настройка Битвы Жуков === │
# ╰───────────────────────────────╯
# ╭──────────────────────────────────────╮
# │ БИТВА НАЧАЛАСЬ!                      │
# │ Джон Леннон (1) VS Пол Маккартни (2) │
# ╰──────────────────────────────────────╯
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 9 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 7 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 14 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 7 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 13 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 13 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 9 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 8 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 13 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 7 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 14 урона!
# ЖУК УБИТ! Джон Леннон получает +10 HP бонус.
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 14 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 23 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 20 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 7 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 22 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 22 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 11 урона!
# ЖУК УБИТ! Пол Маккартни получает +10 HP бонус.
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 22 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 18 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 10 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 7 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 19 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 22 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 8 урона!
# ЖУК УБИТ! Джон Леннон получает +10 HP бонус.
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 6 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 16 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 22 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 24 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 14 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 10 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 6 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 5 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 15 урона!
# ЖУК УБИТ! Пол Маккартни получает +10 HP бонус.
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 7 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 13 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 5 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 15 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 15 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 20 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 17 урона!
# ЖУК УБИТ! Джон Леннон получает +10 HP бонус.
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 10 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 8 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 17 урона!
# ЖУК УБИТ! Пол Маккартни получает +10 HP бонус.
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 19 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 14 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 5 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 15 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 22 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 21 урона!
# ЖУК УБИТ! Пол Маккартни получает +10 HP бонус.
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 13 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 14 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 13 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 14 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 18 урона!
# ЖУК УБИТ! Джон Леннон получает +10 HP бонус.
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 12 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 13 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 24 урона!
# Джон Леннон (1) атакует Пол Маккартни (2) в стиле Джона на 19 урона!
# Пол Маккартни (2) атакует Джон Леннон (1) в стиле Пола на 22 урона!
# ЖУК УБИТ! Пол Маккартни получает +10 HP бонус.
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ПОБЕДИТЕЛЬ: Пол Маккартни (2)!                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
