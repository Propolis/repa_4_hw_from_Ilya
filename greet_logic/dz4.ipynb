# %%
from my_functions import change_name, greet


name = "Моргенштерн"
print(f"Оригинал: {name}")
print(f"Измененный:  {change_name(name)}")


greet("это новый каделак")
# Out:
# Оригинал: Моргенштерн
# Измененный:  мОрГеНшТеРн
# Hello это новый каделак ✨
